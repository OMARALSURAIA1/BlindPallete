# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kritanjalijain/fashion-anchor-cloth-pairs")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 14.3G/14.3G [01:13<00:00, 209MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kritanjalijain/fashion-anchor-cloth-pairs/versions/5

# %%
import os

pants_path = path+'/pants_dataset/pants_dataset/men_pants/cloths'

# %%
# طباعة كل الملفات والمجلدات داخل المسار
files = os.listdir(pants_path)
print(files)
# Out:
# ['menpant1864.png', 'menpant6851.png', 'menpant6153.png', 'menpant1590.png', 'menpant2870.png', 'menpant2753.png', 'menpant8572.png', 'menpant1006.png', 'menpant8199.png', 'menpant7031.png', 'menpant1865.png', 'menpant3153.png', 'menpant9020.png', 'menpant6940.png', 'menpant8548.png', 'menpant3042.png', 'menpant6384.png', 'menpant2814.png', 'menpant5252.png', 'menpant6999.png', 'menpant4421.png', 'menpant5662.png', 'menpant6152.png', 'menpant4339.png', 'menpant6354.png', 'menpant327.png', 'menpant7874.png', 'menpant8536.png', 'menpant2357.png', 'menpant2405.png', 'menpant8088.png', 'menpant1974.png', 'menpant7303.png', 'menpant1770.png', 'menpant7499.png', 'menpant5372.png', 'menpant6760.png', 'menpant3801.png', 'menpant6723.png', 'menpant9711.png', 'menpant4485.png', 'menpant8785.png', 'menpant1192.png', 'menpant6832.png', 'menpant4714.png', 'menpant4746.png', 'menpant406.png', 'menpant1067.png', 'menpant1447.png', 'menpant7054.png', 'menpant5390.png', 'menpant2315.png', 'menpant567
# ...

# %%
import shutil
import os

# Original source path (make sure this matches your actual structure)
source_path = os.path.join(path, 'pants_dataset', 'pants_dataset', 'men_pants', 'cloths')

# Destination path in /content
destination_path = '/content/men_pants_cloths'

# Copy the folder
shutil.copytree(source_path, destination_path)

print(f"✅ تم نسخ مجلد 'cloths' إلى: {destination_path}")
# Out:
# ✅ تم نسخ مجلد 'cloths' إلى: /content/men_pants_cloths

# %%
tshirts_path = path+'/upperwear_dataset/upperwear_dataset/men_top/cloths'

# %%
import os

# طباعة كل الملفات والمجلدات داخل المسار
files = os.listdir(tshirts_path)
print(files)
# Out:
# ['m8943.png', 'm7146.png', 'm10019.png', 'm964.png', 'm3551.png', 'm11433.png', 'm5171.png', 'm3701.png', 'm3068.png', 'm7930.png', 'm12099.png', 'm8530.png', 'm6233.png', 'm4366.png', 'm367.png', 'm8991.png', 'm6133.png', 'm9640.png', 'm2315.png', 'm9314.png', 'm2826.png', 'm8763.png', 'm2412.png', 'm3039.png', 'm6772.png', 'm9217.png', 'm6271.png', 'm7299.png', 'm1807.png', 'm2776.png', 'm3240.png', 'm11139.png', 'm3419.png', 'm2350.png', 'm45.png', 'm8037.png', 'm10003.png', 'm8512.png', 'm6266.png', 'm3026.png', 'm7787.png', 'm9963.png', 'm9565.png', 'm6192.png', 'm7947.png', 'm5282.png', 'm10304.png', 'm3358.png', 'm7526.png', 'm4146.png', 'm11816.png', 'm7910.png', 'm3700.png', 'm2820.png', 'm8443.png', 'm588.png', 'm2699.png', 'm9704.png', 'm4846.png', 'm11497.png', 'm10363.png', 'm6433.png', 'm9473.png', 'm7861.png', 'm5150.png', 'm10431.png', 'm3323.png', 'm1571.png', 'm11813.png', 'm10956.png', 'm1445.png', 'm8054.png', 'm1601.png', 'm104.png', 'm10564.png', 'm9895.png', 'm
# ...

# %%
import shutil
import os

# مسار المجلد المصدر
source_path = os.path.join(path, 'upperwear_dataset', 'upperwear_dataset', 'men_top', 'cloths')

# المسار الهدف داخل مجلد content
destination_path = '/content/men_top_cloths'

# نسخ المجلد بالكامل
shutil.copytree(source_path, destination_path)

print(f"✅ تم نسخ مجلد 'cloths' إلى: {destination_path}")
# Out:
# ✅ تم نسخ مجلد 'cloths' إلى: /content/men_top_cloths

# %%
import zipfile
import os

def zip_folder(folder_path, zip_name):
    with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                abs_path = os.path.join(root, file)
                rel_path = os.path.relpath(abs_path, start=folder_path)
                zipf.write(abs_path, arcname=rel_path)

    print(f"✅ تم ضغط المجلد: {zip_name}")

# %%
zip_folder('/content/men_top_cloths', '/content/men_top_cloths.zip')
# Out:
# ✅ تم ضغط المجلد: /content/men_top_cloths.zip

# %%
zip_folder('/content/men_pants_cloths', '/content/men_pants_cloths.zip')
# Out:
# ✅ تم ضغط المجلد: /content/men_pants_cloths.zip

# %%
import cv2
import matplotlib.pyplot as plt

def print_photo(img_path):
  img = cv2.imread(img_path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  plt.imshow(img)
  plt.axis('off')
  plt.show()

# %%
print_photo(pants_path + "/menpant1032.png")

# %%
print_photo(tshirts_path + "/m10015.png")

# %% [markdown]
# # Detect object using YOLOv8

# %%
# from ultralytics import YOLO
# import cv2
# import os
# from google.colab.patches import cv2_imshow

# # تحميل موديل YOLOv8
# model = YOLO('yolov8n.pt')

# # مسار الصورة
# img_path =pants_path + "/Image_train_10436.jpg"

# # قراءة الصورة
# img = cv2.imread(img_path)

# # كشف الأشخاص
# results = model.predict(img)

# # نختار أكبر صندوق فقط
# max_area = 0
# best_box = None

# for result in results:
#     for box in result.boxes.xyxy:
#         x1, y1, x2, y2 = map(int, box)
#         area = (x2 - x1) * (y2 - y1)  # مساحة الصندوق
#         if area > max_area:
#             max_area = area
#             best_box = (x1, y1, x2, y2)

# # إذا وجدنا أفضل صندوق
# if best_box:
#     x1, y1, x2, y2 = best_box
#     mid_y = (y1 + y2) // 2  # ناخذ النصف السفلي فقط
#     pants_img = img[mid_y:y2, x1:x2]

#     # عرض البنطلون
#     cv2_imshow(pants_img)

#     # حفظ البنطلون
#     save_path = "pants_folder/pants1.jpg"
#     os.makedirs(os.path.dirname(save_path), exist_ok=True)
#     cv2.imwrite(save_path, pants_img)
# else:
#     print("لم يتم الكشف عن أي شخص!")

# %%
# from ultralytics import YOLO
# import cv2
# import os
# from google.colab.patches import cv2_imshow

# # تحميل موديل YOLOv8
# model = YOLO('yolov8n.pt')

# # مسارات المجلدات
# input_folder = pants_path  # مجلد الصور الأصلية
# output_folder = '/content/pants_cut'  # مجلد البنطلونات المقصوصة

# # تأكد أن مجلد الإخراج موجود
# os.makedirs(output_folder, exist_ok=True)


# # المرور على كل الصور
# for filename in os.listdir(input_folder):
#     if filename.endswith(('.jpg', '.png', '.jpeg')):  # فقط صور
#         img_path = os.path.join(input_folder, filename)
#         img = cv2.imread(img_path)

#         if img is None:
#             print(f"تعذر قراءة الصورة: {filename}")
#             continue

#         # كشف الأشخاص
#         results = model.predict(img, verbose=False)

#         max_area = 0
#         best_box = None

#         for result in results:
#             for box in result.boxes.xyxy:
#                 x1, y1, x2, y2 = map(int, box)
#                 area = (x2 - x1) * (y2 - y1)
#                 if area > max_area:
#                     max_area = area
#                     best_box = (x1, y1, x2, y2)

#         if best_box:
#             x1, y1, x2, y2 = best_box
#             mid_y = (y1 + y2) // 2  # قص النصف السفلي
#             pants_img = img[mid_y:y2, x1:x2]

#             # حفظ البنطلون
#             save_path = os.path.join(output_folder, f"pants_{filename}")
#             cv2.imwrite(save_path, pants_img)

#             # عرض البنطلون المقطوع مباشرة
#             print(f"✅ تم حفظ البنطلون: {save_path}")
#             cv2_imshow(pants_img)

#         else:
#             print(f"❌ لم يتم الكشف عن شخص في الصورة: {filename}")

# %%
import zipfile
def open_zip(zip_path,extract_folder):
  # فك الضغط
  with zipfile.ZipFile(zip_path, 'r') as zip_ref:
      zip_ref.extractall(extract_folder)

  print("✅ تم فك الضغط بنجاح!")

# %%
open_zip('/content/cropped_pants_test.zip','/content/pants_test')
# Out:
# ✅ تم فك الضغط بنجاح!

# %%
open_zip('/content/cropped_pants.zip','/content/pants_train')
# Out:
# ✅ تم فك الضغط بنجاح!

# %%
import os
import cv2
import numpy as np

# مسارات الملفات
pants_train_folder = '/content/pants_train'    # البنطلونات (train)
pants_test_folder = '/content/pants_test'     # البنطلونات (test)
tops_folder = tshirts_path                  # البلايز

# دالة التحضير
def load_and_preprocess_images(folder_path, target_size=(128, 128)):
    images = []
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.png', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                img = img.astype('float32') / 255.0  # Normalization
                images.append(img)
    return np.array(images)

# تجهيز كل المجموعات
pants_train_images = load_and_preprocess_images(pants_train_folder)
pants_test_images = load_and_preprocess_images(pants_test_folder)
tops_images = load_and_preprocess_images(tops_folder)

# طباعة أشكال البيانات للتأكيد
print(f"👖 صور تدريب البناطيل:", pants_train_images.shape)
print(f"👖 صور اختبار البناطيل:", pants_test_images.shape)
print(f"👕 صور البلايز:", tops_images.shape)
# Out:
# 👖 صور تدريب البناطيل: (15745, 128, 128, 3)
# 👖 صور اختبار البناطيل: (5162, 128, 128, 3)
# 👕 صور البلايز: (1993, 128, 128, 3)

# %%
# دمج البلايز والبناطيل في مجموعة تدريب واحدة
train_images = np.concatenate([pants_train_images, tops_images], axis=0)

# طباعة شكل البيانات الجديد
print(f"📦 شكل بيانات التدريب الكاملة:", train_images.shape)
# Out:
# 📦 شكل بيانات التدريب الكاملة: (17738, 128, 128, 3)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

# 1. Encoder
def build_encoder(latent_dim):
    encoder_inputs = layers.Input(shape=(128, 128, 3))
    x = layers.Conv2D(32, 3, activation='relu', strides=2, padding='same')(encoder_inputs)
    x = layers.Conv2D(64, 3, activation='relu', strides=2, padding='same')(x)
    x = layers.Conv2D(128, 3, activation='relu', strides=2, padding='same')(x)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)

    z_mean = layers.Dense(latent_dim, name='z_mean')(x)
    z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)

    # Sampling Layer
    def sampling(args):
        z_mean, z_log_var = args
        epsilon = tf.random.normal(shape=(tf.shape(z_mean)[0], latent_dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    z = layers.Lambda(sampling, name='z')([z_mean, z_log_var])

    encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
    return encoder

# 2. Decoder
def build_decoder(latent_dim):
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(16 * 16 * 128, activation='relu')(decoder_inputs)
    x = layers.Reshape((16, 16, 128))(x)
    x = layers.Conv2DTranspose(128, 3, activation='relu', strides=2, padding='same')(x)
    x = layers.Conv2DTranspose(64, 3, activation='relu', strides=2, padding='same')(x)
    x = layers.Conv2DTranspose(32, 3, activation='relu', strides=2, padding='same')(x)
    decoder_outputs = layers.Conv2DTranspose(3, 3, activation='sigmoid', padding='same')(x)

    decoder = Model(decoder_inputs, decoder_outputs, name="decoder")
    return decoder

# 3. بناء الـ VAE مع Loss Function
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def compile(self, optimizer):
        super(VAE, self).compile()
        self.optimizer = optimizer
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(data - reconstruction), axis=(1,2,3)))
            kl_loss = -0.5 * tf.reduce_mean(tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1))
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
latent_dim = 32  # حسب اختيارك

# بناء الموديلات
encoder = build_encoder(latent_dim)
decoder = build_decoder(latent_dim)
vae = VAE(encoder, decoder)

# تحديد الـ optimizer
optimizer = tf.keras.optimizers.Adam()

# تجهيز الموديل للتدريب
vae.compile(optimizer=optimizer)

# %%
vae.fit(train_images, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - kl_loss: 57.6314 - loss: 4100.4795 - reconstruction_loss: 4042.8481
# Epoch 2/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 74.0070 - loss: 1972.8291 - reconstruction_loss: 1898.8224
# Epoch 3/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 82.5611 - loss: 1191.7401 - reconstruction_loss: 1109.1790
# Epoch 4/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 83.4953 - loss: 1075.8423 - reconstruction_loss: 992.3474
# Epoch 5/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 84.8986 - loss: 988.1252 - reconstruction_loss: 903.2266
# Epoch 6/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 86.2569 - loss: 903.4003 - reconstruction_loss: 817.1433
# Epoch 7/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 86.4654 - loss: 866.0861 - reconstruction_loss: 779.6208
# Epoch 8/50
# ...

# %%
vae.save("vae_full_model.h5")  # إذا كنت تفضل صيغة .h5 القديمة
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# افترض عندك صور البلايز بعد Preprocessing باسم tops_images
tops_latent_vectors = encoder.predict(tops_images)[0]  # نأخذ z_mean
print("شكل التمثيل العددي للبلايز:", tops_latent_vectors.shape)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step
# شكل التمثيل العددي للبلايز: (1993, 32)

# %%
from sklearn.metrics.pairwise import euclidean_distances

def find_best_matching_tops(pants_img_array, top_latents, tops_paths):
    z_mean, _, _ = encoder.predict(np.expand_dims(pants_img_array, axis=0))
    distances = euclidean_distances(z_mean, top_latents)
    best_index = np.argmin(distances)
    return tops_paths[best_index]

# %%
import os

tops_paths = []
tops_folder = tshirts_path #'/content/pants_cut/train'  # تأكد من مسار مجلد البلايز

for filename in sorted(os.listdir(tops_folder)):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        tops_paths.append(os.path.join(tops_folder, filename))

print(f"عدد البلايز:", len(tops_paths))
# Out:
# عدد البلايز: 1993

# %%
pants_img_path ='/content/pants_test/pants_Image_test_00011.jpg'  # مسار بنطالك الجديدة
pants_img = cv2.imread(pants_img_path)
pants_img = cv2.cvtColor(pants_img, cv2.COLOR_BGR2RGB)
pants_img = cv2.resize(pants_img, (128, 128))
pants_img = pants_img.astype('float32') / 255.0

# %%
best_tops_path = find_best_matching_tops(pants_img, tops_latent_vectors, tops_paths)
print("أفضل بنطلون للبلوزة:", best_tops_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# أفضل بنطلون للبلوزة: /kaggle/input/tshirts/tshirt/620.jpg

# %%
def merge_top_bottom(top_img_path, bottom_img_path, output_size=(256, 512)):
    top_img = cv2.imread(top_img_path)
    bottom_img = cv2.imread(bottom_img_path)

    top_img = cv2.cvtColor(top_img, cv2.COLOR_BGR2RGB)
    bottom_img = cv2.cvtColor(bottom_img, cv2.COLOR_BGR2RGB)

    top_img = cv2.resize(top_img, (output_size[0], output_size[1]//2))
    bottom_img = cv2.resize(bottom_img, (output_size[0], output_size[1]//2))

    combined_img = np.vstack((top_img, bottom_img))
    return combined_img

# عرض النتيجة
outfit_image = merge_top_bottom(best_tops_path, pants_img_path)

import matplotlib.pyplot as plt
plt.figure(figsize=(4,8))
plt.imshow(outfit_image)
plt.axis('off')
plt.show()

# %%
# !pip install umap-learn

# %%
import umap
import matplotlib.pyplot as plt
import cv2
import numpy as np

# 🔹 1. تجهيز latent vectors للبلايز (مسبقًا عندك)
# tops_latent_vectors = ...

# 🔹 2. تجهيز صورة البنطلون الجديد
pants_img_path = '/content/pants_test/pants_Image_test_00004.jpg'
img = cv2.imread(pants_img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (128, 128))
img = img.astype('float32') / 255.0

pants_vector = encoder.predict(np.expand_dims(img, axis=0))[0]  # z_mean فقط

# 🔹 3. دمج البنطلون مع البلايز في latent space
all_vectors = np.vstack([tops_latent_vectors, pants_vector])

# 🔹 4. تطبيق UMAP
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
embedding = reducer.fit_transform(all_vectors)

# 🔹 5. الرسم: البلايز بالأزرق، البنطلون بالأحمر
plt.figure(figsize=(10, 8))
plt.scatter(embedding[:-1, 0], embedding[:-1, 1], color='skyblue', label='Tops')
plt.scatter(embedding[-1, 0], embedding[-1, 1], color='red', label='Query Pants 🔴', s=100)
plt.title("UMAP of Tops Latent Space + Pants Query")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
embedding = tsne.fit_transform(all_vectors)

# الرسم نفس الشي
plt.figure(figsize=(10, 8))
plt.scatter(embedding[:-1, 0], embedding[:-1, 1], color='skyblue', label='Tops')
plt.scatter(embedding[-1, 0], embedding[-1, 1], color='red', label='Query Pants 🔴', s=100)
plt.title("t-SNE of Tops Latent Space + Pants Query")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
import cv2
import numpy as np

# 1. تجهيز صور الملابس (مثلاً البلايز)
folder = tshirts_path
images = []
colors = []

def extract_color(img):
    return np.mean(img.reshape(-1, 3), axis=0) / 255.0

for file in sorted(os.listdir(folder)):
    if file.endswith(('.jpg', '.png')):
        path = os.path.join(folder, file)
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (128, 128))
        img_norm = img.astype('float32') / 255.0

        images.append(img_norm)
        colors.append(extract_color(img))

images = np.array(images)
colors = np.array(colors)

# %%
latent_vectors = encoder.predict(images)[0]  # z_mean فقط
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# !pip install umap-learn

import umap
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
embedding = reducer.fit_transform(latent_vectors)
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
embedding = tsne.fit_transform(latent_vectors)

# %%
plt.figure(figsize=(10, 8))
for i in range(len(embedding) - 1):
    plt.scatter(embedding[i, 0], embedding[i, 1], color=colors[i], s=30)

# النقطة الأخيرة هي البنطلون
plt.scatter(embedding[-1, 0], embedding[-1, 1], color='red', s=150, marker='X', label='Query Pants 🔴')

plt.title("🎨 Latent Space with Pants Query")
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# 🔹 دالة تجهيز الصورة
def prepare_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"❌ تعذر تحميل الصورة: {image_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    img = img.astype('float32') / 255.0
    return img

# 🔹 دالة التوصية من الدولاب
def recommend_top_tops_for_pants(pants_img_path, encoder, tops_latent_vectors, tops_paths, top_n=20):
    pants_img = prepare_image(pants_img_path)
    pants_vector = encoder.predict(np.expand_dims(pants_img, axis=0))[0]  # z_mean

    similarities = cosine_similarity(pants_vector, tops_latent_vectors)
    top_indices = similarities[0].argsort()[::-1][:top_n]

    top_paths = [tops_paths[i] for i in top_indices]
    top_scores = [similarities[0][i] for i in top_indices]

    return top_paths, top_scores

# 🔹 دالة عرض الصور مع نسب التشابه
def show_images_with_similarity(image_paths, similarity_scores, title="نتائج التوصية", max_cols=5):
    total = len(image_paths)
    cols = min(total, max_cols)
    rows = (total + cols - 1) // cols

    plt.figure(figsize=(3*cols, 3*rows))

    for i, (path, score) in enumerate(zip(image_paths, similarity_scores)):
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.subplot(rows, cols, i+1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(f"{i+1}. : {score:.2f}")

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
# 🧵 مسار البنطلون اللي تبغى تسوي عليه استعلام
query_pants_path = '/content/pants_test/pants_Image_test_00005.jpg'

# 🧺 الدولاب الثابت = 20 بلوزة فقط (صورهم جاهزة مسبقًا)
tops_latent_vectors = encoder.predict(tops_images[:20])[0]
tops_paths = tops_paths[:20]

# 🚀 تشغيل التوصية
recommended_tops, top_scores = recommend_top_tops_for_pants(
    query_pants_path,
    encoder,
    tops_latent_vectors,
    tops_paths,
    top_n=20
)

# 🖼️ عرض النتائج بصريًا
show_images_with_similarity(recommended_tops, top_scores, title="👕 أفضل 20 بلوزة متناسقة مع البنطلون")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# <ipython-input-43-4a76cd60a595>:46: UserWarning: Glyph 128085 (\N{T-SHIRT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128085 (\N{T-SHIRT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
